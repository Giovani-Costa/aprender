# %%
print('Hello World')
# Out:
# Hello World

# %%
nome = 'Giovani'
idade = 15
altura = 1.70
is_student = True
# Out:
# True

# %%
num1 = int(input('Digite o primeiro número: '))
num2 = int(input('Digite o segundo número: '))
print(f'{num1} + {num2} = {num1 + num2}')

num1 = int(input('Digite o primeiro número: '))
num2 = int(input('Digite o segundo número: '))
print(f'{num1} - {num2} = {num1 - num2}')
# Out:
# Digite o primeiro número: 890
# Digite o segundo número: 7656
# 890 + 7656 = 8546
