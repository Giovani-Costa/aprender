# %%
num = int(input('Diga um número inteiro positivo: '))
produtos_impares = 1
produtos_pares = 1

for k in range(1, num+1):
    if k % 2 == 0:
        produtos_pares *= k
    else:
        produtos_impares *= k

print(f'\nResultado do produto de todos os números pares é {produtos_pares}.\nResultado do produto de todos os números pares é {produtos_pares}.')
# Out:
# Diga um número inteiro positivo: 5
#
# Resultado do produto de todos os números pares é 8.
# Resultado do produto de todos os números pares é 8.

# %%
contador = 0
a = int(input("Digite um número: "))
b = int(input("Digite um número: "))
c = int(input("Digite um número: "))

for k in range(a, b + 1):
  if k % c == 0:
    contador += 1
print(f'Foram encontrados {contador} números divisíveis por {c}')
